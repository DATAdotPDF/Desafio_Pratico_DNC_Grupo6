# %% [markdown]
# # 📊 {INSIRA SEU PROJETO} – {BASE DE DADOS} ({ESCOLA/GRUPO DE ESTUDO}) {ANO}

# %% [markdown]
# ## 🎯 Objetivos
# - Descreva aqui os objetivos do seu projeto
# - Ex: analisar dados públicos, aplicar limpeza e gerar visualizações

# %% [markdown]
# ## ⚙️ Instalação de Pacotes e Bibliotecas

# %%
# Instalação de pacotes (ajuste conforme necessidade)
# %pip install pandas matplotlib seaborn openpyxl --quiet

# %%
# Importações essenciais
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## 📥 Leitura dos Arquivos
# Descreva como os dados serão carregados (direto da web, Drive, etc.)

# %%
# caminho_arquivo = '/content/drive/MyDrive/seu_arquivo.xlsx'
df = pd.read_excel(caminho_arquivo)
df.head()

# %% [markdown]
# ## 🧼 Tratamento e Limpeza de Dados
# Aqui você pode remover colunas, tratar nulos, renomear, padronizar formatos, etc.

# %%
# Exemplo:
df.columns = df.columns.str.strip()
df = df.dropna()
df = df.rename(columns={'Antiga': 'Nova'})

# %% [markdown]
# ## 📊 Visualizações e Análises
# Gráficos, estatísticas, correlações, rankings

# %%
# sns.barplot(data=df, x='Categoria', y='Valor')
# plt.title('Exemplo')
# plt.show()

# %% [markdown]
# ## 💾 Exportação de Dados Tratados

# %%
# df.to_excel('/content/arquivo_tratado.xlsx', index=False)
